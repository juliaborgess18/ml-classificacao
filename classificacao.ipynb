# %%
import pandas as pd
arquivo = pd.read_csv('C:/Users/julia/Desktop/Projetos ML/Classificação de Vinhos/wine_dataset.csv')

# %%
arquivo.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality style
# 0      9.4        5   red
# 1      9.8        5   red
# 2      9.8        5   red
# 3      9.8        6   red
# 4      9.4        5   red

# %%
arquivo['style'] = arquivo['style'].replace('red',0)

# %%
arquivo['style'] = arquivo['style'].replace('white',1)

# %%
arquivo.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  style
# 0      9.4        5      0
# 1      9.8        5      0
# 2      9.8        5      0
# 3      9.8        6      0
# 4      9.4        5      0

# %%
y = arquivo['style']
x = arquivo.drop('style', axis=1)

# %%
from sklearn.model_selection import train_test_split

x_treino, x_teste, y_treino, y_teste = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.ensemble import ExtraTreesClassifier

modelo = ExtraTreesClassifier()
modelo.fit(x_treino,y_treino)

resultado = modelo.score(x_teste, y_teste)
print("Acurácia:", resultado)
# Out:
# Acurácia: 0.9948717948717949

# %%
y_teste[400:403]
# Out:
# 762     0
# 4988    1
# 3362    1
# Name: style, dtype: int64

# %%
x_teste[400:403]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 762             8.8              0.70          0.0             1.7      0.069
# 4988            6.6              0.24          0.3            11.3      0.026
# 3362            7.3              0.21          0.3            10.9      0.037
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 762                   8.0                  19.0  0.99701  3.31       0.53
# 4988                 11.0                  77.0  0.99381  3.13       0.55
# 3362                 18.0                 112.0  0.99700  3.40       0.50
#
#       alcohol  quality
# 762      10.0        6
# 4988     12.8        7
# 3362      9.6        6

# %%
previsoes = modelo.predict(x_teste[400:403])

# %%
previsoes
# Out:
# array([0, 1, 1], dtype=int64)
